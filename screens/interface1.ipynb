# %%
from sqlalchemy import create_engine
import pandas as pd

# Credenciais do banco rodando no Docker
USUARIO = "postgres"
SENHA = "postgres"
HOST = "127.0.0.1"   # IP local seguro
PORTA = "5432"
BANCO = "trabalho_fbd"

DATABASE_URL = f"postgresql+psycopg2://{USUARIO}:{SENHA}@{HOST}:{PORTA}/{BANCO}"
engine = create_engine(DATABASE_URL)

print("🎉 SUCESSO! Conexão com o banco estabelecida com segurança!")
# Out:
# 🎉 SUCESSO! Conexão com o banco estabelecida com segurança!
